# %% [markdown]
#   # TASK - 7 (OOPS)

# %% [markdown]
# ## **Problem Statement**
# - Create a class to control a smart light that can be turned ON or OFF and display its status.
#
# **Real-Time Use**
# - Smart home automation systems
#
# **Sample Input**
# - Light Name: Bedroom Light
# - Action: ON
#
# **Expected Output**
# - Bedroom Light is ON

# %%
class SmartLight:

  def __init__(self, name):
    self.name = name
    self.is_on = False

  def turn_on(self):         # Turning on the lights
    self.is_on = True

  def turn_off(self):        # Turning off the lights
    self.is_on = False

  def status(self):          # Updating the status
    if self.is_on:
      print(self.name, "is ON")
    else:
      print(self.name, "is OFF")


# Creating Object
smart_light = SmartLight("Bedroom Light")

# Method Calling
smart_light.turn_on()
smart_light.status()
# Out:
# Bedroom Light is ON

# %% [markdown]
# ## **Problem 2: Employee ID Card System**
# **Problem Statement**
# - Create a class that stores employee name, ID, and department and displays ID card details.
#
# **Real-Time Use**
# - Corporate HR systems
#
# **Sample Input**
# - Employee Name: Rahul
# - Employee ID: EMP102
# - Department: IT
#
# **Expected Output**
# - Employee ID Card
# - Name: Rahul
# - ID: EMP102
# - Department: IT

# %%
class EmployeeIDCard:

  def __init__(self, name, id, department):
    self.name = name
    self.id = id
    self.department = department

  def display_details(self):                # Deplaying the employee details
    print("Employee ID Card")
    print("Name:", self.name)
    print("ID:", self.id)
    print("Department:", self.department)

# Creating the object
employee = EmployeeIDCard("Rahul", "EMP102", "IT")

# Method Calling
employee.display_details()
# Out:
# Employee ID Card
# Name: Rahul
# ID: EMP102
# Department: IT

# %% [markdown]
# ## **Problem 3: Mobile Contact Record**
# **Problem Statement**
# - Create a class to store contact name and phone number and display contact information.
#
# **Real-Time Use**
# - Mobile contact applications
#
# **Sample Input**
# - Contact Name: Anita
# - Phone Number: 9876543210
#
# **Expected Output**
# - Contact Saved
# - Name: Anita
# - Phone: 9876543210

# %%
class mobile_contact:

  def __init__(self, name, phone):
    self.name = name
    self.phone = phone

  def display_details(self):               # Displaying the contact details
    print("Contact Saved")
    print("Name:", self.name)
    print("Phone:", self.phone)

# Object Creating
contact = mobile_contact("Anita", "9876543210")

# Method Calling
contact.display_details()
# Out:
# Contact Saved
# Name: Anita
# Phone: 9876543210

# %% [markdown]
# ## **Problem 4: Product Price Tag Generator**
# **Problem Statement**
# - Create a class that stores product name and price and prints a formatted price tag.
#
# **Real-Time Use**
# - Retail billing systems
#
# **Sample Input**
# - Product Name: Headphones
# - Price: 2499
#
# **Expected Output**
# - Product: Headphones
# - Price: ₹2499

# %%
class Price_tag:

  def __init__(self, name, price):
    self.name = name
    self.price = price

  def display_price_tag(self):              # Displaying Product price tag
    print(f"Product: {self.name}")
    print(f"Price: {self.price}/-")

# Object Creating
product = Price_tag("Headphones", 2499)

# Method Calling
product.display_price_tag()
# Out:
# Product: Headphones
# Price: 2499/-

# %% [markdown]
# ## **Problem 5: Movie Rating Display System**
# **Problem Statement**
# - Create a class that stores movie name and rating and displays movie details.
#
# **Real-Time Use**
# - Streaming platforms
#
# **Sample Input**
# - Movie Name: Inception
# - Rating: 4.8
#
# **Expected Output**
# - Movie: Inception
# - Rating: 4.8 / 5

# %%
class Movie_rating:

  def __init__(self, name, rating):
    self.name = name
    self.rating = rating

  def display_movie_rating(self):           # Displays movie details.
    print("Movie:", self.name)
    print("Rating:", self.rating,"/5")


# Object Calling
movie = Movie_rating("Inception", 4.8)

# Method Calling
movie.display_movie_rating()
# Out:
# Movie: Inception
# Rating: 4.8 /5

# %% [markdown]
# ## **Problem 6: Delivery Address Manager**
# **Problem Statement**
# - Create a class that stores customer name and delivery address and prints delivery details.
#
# **Real-Time Use**
# - Courier and logistics platforms
#
# **Sample Input**
# - Customer Name: Suman
# - Address: Hyderabad
#
# **Expected Output**
# - Delivery Details
# - Customer: Suman
# - Address: Hyderabad

# %%
class DeliveryAddress:

  def __init__(self, name, address):
    self.name = name
    self.address = address

  def display_delivery_details(self):       # Displaying the delivery details
    print("Delivery Details")
    print("Customer:", self.name)
    print("Address:", self.address)

# Object Creating
customer = DeliveryAddress("Suman", "Hyderabad")

# Method Calling
customer.display_delivery_details()
# Out:
# Delivery Details
# Customer: Suman
# Address: Hyderabad
