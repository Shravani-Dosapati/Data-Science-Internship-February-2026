# %% [markdown]
# # Logic Building Task – 1

# %% [markdown]
# ### **1. User Login Check**
#
# **Problem Statement:**
#
# Given a username and password, check whether login is successful.
# - username = "admin"
# - password = "1234"
#
# Requirements:
# - Print "Login Successful" if both username and password match
# - Otherwise print "Invalid Credentials"
#
# Real-World Application: Authentication systems

# %%
username = "admin"
password = "1234"

input_username = input("Enter your username: ")  # Taking user input
input_password = input("Enter your password: ")  # Taking user password

if input_username == username and input_password == password:      # checking if the credentials match
  print("Login Successful")
else:
  print("Invalid Credentials")
# Out:
# Enter your username: admin
# Enter your password: 1234
# Login Successful

# %% [markdown]
# ### **2. Pass / Fail Analyzer**
#
# **Problem Statement:**
#
# Analyze student results.
# - marks = [45, 78, 90, 33, 60]
#
# Requirements:
# - A student passes if marks ≥ 50
# - Count the total number of pass students
# - Count the total number of fail students
# - Print the final result clearly
#
# Real-World Application: Academic evaluation systems

# %%
marks = [45, 78, 90, 33, 60]

pass_students = 0
fail_students = 0

for mark in marks:         # For Loop to segregate pass and fail students
  if mark >= 50:
    pass_students += 1
  else:
    fail_students += 1

print("Total number of pass students:", pass_students)
print("Total number of fail students:", fail_students)
# Out:
# Total number of pass students: 3
# Total number of fail students: 2

# %% [markdown]
# ### **3. Simple Data Cleaner**
#
# **Problem Statement:**
#
# Clean and standardize user names.
# - names = [" Alice ", "bob", " CHARLIE "]
#
# Requirements:
# - Remove extra spaces
# - Convert all names to lowercase
# - Print the cleaned list
#
# Real-World Application: Data preprocessing before analysis

# %%
names = [" Alice ", "bob", " CHARLIE "]

cleaned_names = []

for name in names:
  s = ""
  for n in name:
    if n != " ":       # checking of blank spaces
      s += n.lower()   # converting the name to lowercase
  cleaned_names.append(s)

print(cleaned_names)
# Out:
# ['alice', 'bob', 'charlie']

# %% [markdown]
# ### **4. Message Length Analyzer**
#
# **Problem Statement:**
#
# Analyze message sizes.
# - messages = ["Hi", "Welcome to the platform", "OK"]
#
# Requirements:
# - Print the length of each message
# - Flag messages longer than 10 characters
#
# Real-World Application: Text filtering and validation systems

# %%
messages = ["Hi", "Welcome to the platform", "OK"]

for message in messages:
  print(f"message: {message} \nlength: {len(message)}")

  if len(message) >10:
    print("This message is longer than 10 characters\n")      # Flag the sentence is more than 10 characters
  print()
# Out:
# message: Hi
# length: 2
#
# message: Welcome to the platform
# length: 23
# This message is longer than 10 characters
#
#
# message: OK
# length: 2

# %% [markdown]
# ### 5. **Error Message Detector**
#
# **Problem Statement:**
#
# Detect error messages from system logs.
# - logs = ["INFO", "ERROR", "WARNING", "ERROR"]
#
# Requirements:
# - Count the number of "ERROR" entries
# - Print the total error count
#
# Real-World Application: Monitoring and log analysis systems

# %%
logs = ["INFO", "ERROR", "WARNING", "ERROR"]

errors = 0

for log in logs:
  if log.lower() == "error":
    errors += 1

print("Total error occured in log are:", errors)
# Out:
# Total error occured in log are: 2
